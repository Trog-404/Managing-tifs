# %% [raw]
# Questo notebook è utile per una prima esplorazione dei formati tiff che i vostri strumenti sono in grado di esportare. I codici e i metodi presenti potrebbero non essere totalmente esaustivi. In quel caso non esitate a contattare a mbontorno@fbk.it se avete necessità di aiuto o se in autonomia trovate delle soluzioni che possono essere integrate con il codice presente alla pagina git-hub https://github.com/Trog-404/Characterization-utilities.git per arricchirlo siete i benvenuti.

# %%
import re
import matplotlib.pyplot as plt
import tifffile as tf
import numpy as np

# %% [raw]
# Nel SEM è importante caricare i dati provenienti dalle immagini per cui dobbiamo caricare i dati presenti nella cartella tiffs_for_sem.
# Creiamo la funzione per estrarre i dati dall'immagine. Ho previsto il caso in cui ci possano essere più pagine per cui attualmente la funzione restituisce il nome del file da cui estrae i dati e i dati in una lista per ciascuna pagina.

# %%
def extract_data_from_tif(tif_image):
    name = tif_image.split("/")[-1]
    name = name.split(".")[0]
    with tf.TiffFile(tif_image) as tiffile:
        arrays=[]
        for i, page in enumerate(tiffile.pages):
            array = page.asarray()
            arrays.append(array)
    return name, arrays

# %% [raw]
# Nel codice reale impiegato per nomad in realrà si sta già lavorando pagina per pagina nel parsing dei dati quindi la funzione non è direttamente richiamata ma è presente amalgamata e semplificata nella funzione.

# %% [raw]
# E vediamo come funziona con qualche comando nella prossima cella.

# %%
name, data = extract_data_from_tif("./File_per_sem/tiffs_for_sem/DIC_60nm_07.tif")

print(name)
print(len(data))
data
# Out:
# DIC_60nm_07
# 1
# [array([[146, 139, 143, ..., 193, 200, 199],
#         [146, 146, 146, ..., 198, 200, 196],
#         [157, 147, 158, ..., 198, 199, 199],
#         ...,
#         [ 25,  25,  33, ...,  35,  39,  37],
#         [ 28,  26,  30, ...,  40,  40,  36],
#         [ 25,  28,  29, ...,  34,  42,  37]],
#        shape=(768, 1024), dtype=uint8)]

# %% [raw]
# In questo caso notiamo che la funzione ci ha restituito una array bidimensionale fatto di oggetti di tipo uint8. Non sarebbe stato nemmeno un problema se l'immagine avesse esportato canali rgb o rgba come si vede nella prossima cella. Però NOMAD non supporta ancora il formato RBG ed RGBA per cui quoi formati non verrebbero visualizzati correttamente nelle pagine.

# %%
name, data = extract_data_from_tif("./File_per_sem/tiffs_for_sem/DIC_60nm_07.tif")
print(f"Shape dell'array: {data[0].shape}")
print(f"Tipo di valori nell'array: {data[0].dtype}")
plt.axis('off')
plt.title(name)
plt.imshow(data[0], 'gray')
# Out:
# Shape dell'array: (768, 1024)
# Tipo di valori nell'array: uint8

# %%
name, data = extract_data_from_tif("./File_per_sem/tiffs_for_sem/Matteo_Bontorno_FIB_Images/6144_4096_24bit_ETD_Bar_Overlay_RealOverlay_011.tif")
print(f"Shape dell'array: {data[0].shape}")
print(f"Tipo di valori nell'array: {data[0].dtype}")
plt.axis('off')
plt.title(name)
plt.imshow(data[0])
# Out:
# Shape dell'array: (4376, 6144, 3)
# Tipo di valori nell'array: uint8

# %% [raw]
# Quindi se sei arrivato fin qui e sei riuscito a visualizzare immagini e tipi ottimo... Hai completato la parte più facile del lavoro.

# %% [raw]
# Qualora tu avessi avuto dei problemi potrebbero essere dovuti principalmente al non lavorare con un formato .tif o .tiff. In questo caso nella prossima cella cè una piccola routine realizzata con la libreria PIL per ottenere l'immagine. È comunque consigliato riuscire a lavorare con i tiff perché nella mia esperienza risultano più semplici da maneggaire e controllare ma ove possibile darò delle alternative con il pacchetto PIL.

# %%
from PIL import Image

# %%
def extract_data_from_image_pilversion(tif_image):
    name = tif_image.split("/")[-1].split(".")[0]
    arrays = []

    with Image.open(tif_image) as img:
        i = 0
        while True:
            try:
                img.seek(i)  # vai alla pagina i
                arrays.append(np.array(img))  # converto in numpy array
                i += 1
            except EOFError:
                break  # fine delle pagine

    return name, arrays

# %% [raw]
# Che sarebbe una possibile versione del codice precedente scritto con tifffile.

# %%
name, data = extract_data_from_image_pilversion("./File_per_sem/tiffs_for_sem/2025_08_31_U2280_Electrodes_GePP_HR_3um.tif")

print(name)
data
# Out:
# 2025_08_31_U2280_Electrodes_GePP_HR_3um
# [array([[247, 247, 164, ..., 247,   7, 164],
#         [  7, 164, 247, ..., 164, 247, 164],
#         [164, 247,  91, ..., 247, 164, 247],
#         ...,
#         [164, 164, 164, ..., 164, 164, 155],
#         [ 82,  91, 155, ..., 247, 247, 164],
#         [  0,   0,   0, ..., 247, 247, 247]], shape=(512, 512), dtype=uint8)]

# %% [raw]
# E come vedete la funzoine riporta lo stesso risultato della precedente. Se proviamo poi ad analizzare un formato diverso tipo il bmp:

# %%
name, data = extract_data_from_image_pilversion("./File_per_sem/tiffs_for_sem/2025_08_31 U2280_Electrodes_GePP_HR_3um_001.bmp")

print(name)
data
# Out:
# 2025_08_31 U2280_Electrodes_GePP_HR_3um_001
# [array([[[168, 168, 168],
#          [148, 148, 148],
#          [129, 129, 129],
#          ...,
#          [168, 168, 168],
#          [184, 184, 184],
#          [121, 121, 121]],
#
#         [[177, 177, 177],
#          [142, 142, 142],
#          [147, 147, 147],
#          ...,
#          [141, 141, 141],
#          [156, 156, 156],
#          [121, 121, 121]],
#
#         [[137, 137, 137],
#          [162, 162, 162],
#          [ 93,  93,  93],
#          ...,
#          [145, 145, 145],
#          [132, 132, 132],
#          [145, 145, 145]],
#
#         ...,
#
#         [[118, 118, 118],
#          [112, 112, 112],
#          [126, 126, 126],
#          ...,
#          [124, 124, 124],
#          [142, 142, 142],
#          [100, 100, 100]],
#
#         [[ 48,  48,  48],
#          [ 84,  84,  84],
#          [109, 109, 109],
#          ...,
#          [152, 152, 152],
#          [152, 152, 152],
#          [118, 118, 118]],
#
# ...

# %% [raw]
# Riusciamo anche questo caso ad esportare correttamente i dati ma se usassimo la versione precedente.

# %%
name, data = extract_data_from_image_pilversion("./File_per_sem/tiffs_for_sem/2025_08_31 U2280_Electrodes_GePP_HR_3um_001.bmp")

print(name)
data
# Out:
# 2025_08_31 U2280_Electrodes_GePP_HR_3um_001
# [array([[[168, 168, 168],
#          [148, 148, 148],
#          [129, 129, 129],
#          ...,
#          [168, 168, 168],
#          [184, 184, 184],
#          [121, 121, 121]],
#
#         [[177, 177, 177],
#          [142, 142, 142],
#          [147, 147, 147],
#          ...,
#          [141, 141, 141],
#          [156, 156, 156],
#          [121, 121, 121]],
#
#         [[137, 137, 137],
#          [162, 162, 162],
#          [ 93,  93,  93],
#          ...,
#          [145, 145, 145],
#          [132, 132, 132],
#          [145, 145, 145]],
#
#         ...,
#
#         [[118, 118, 118],
#          [112, 112, 112],
#          [126, 126, 126],
#          ...,
#          [124, 124, 124],
#          [142, 142, 142],
#          [100, 100, 100]],
#
#         [[ 48,  48,  48],
#          [ 84,  84,  84],
#          [109, 109, 109],
#          ...,
#          [152, 152, 152],
#          [152, 152, 152],
#          [118, 118, 118]],
#
# ...

# %% [raw]
# Ok adesso però dobbiamo capire la forma dei metadati che dovremo scrivere nel file NeXus. Attualmente il plugin prevede il parsing corretto dei dati che provengono dai segenti struementi:
#
# -TESCAN NISABA
# -FEI_HELIOS
# -RAITH_VELION*
#
# Alcuni strumenti del gruppo FEI potrebbero già essere perfettamente compatibili e basterebbe inserire solo la lista dei matchers richieste e le entry necessarie nella funzione load_matchers.
#
# * Il raith in realtà va preprocessato per integrare i dati provenienti da file .scc separato.

# %%
def analyze_metadata_from_tif(tif_file):
    with tf.TiffFile(tif_file) as tif:
        page = tif.pages[0]
        for tag in page.tags:
            print(f"{tag.name} has code {tag.code}")

# %% [raw]
# Attualmente ci sono quattro casi possibili come output di analisi...

# %% [raw]
# La prima e che vi auguro sia presente questa per voi nell'analisi i tags del file TIFF sono perfettamente formattati e leggibili come accade nella prossima cella.

# %%
analyze_metadata_from_tif('./File_per_sem/tiffs_for_sem/DIC_60nm_07.tif')
# Out:
# NewSubfileType has code 254
# ImageWidth has code 256
# ImageLength has code 257
# BitsPerSample has code 258
# Compression has code 259
# PhotometricInterpretation has code 262
# ImageDescription has code 270
# StripOffsets has code 273
# SamplesPerPixel has code 277
# RowsPerStrip has code 278
# StripByteCounts has code 279
# XResolution has code 282
# YResolution has code 283
# ResolutionUnit has code 296
# ColorMap has code 320
# CZ_SEM has code 34118

# %%
analyze_metadata_from_tif('./File_per_sem/tiffs_for_sem/Matteo_Bontorno_FIB_Images/1024_884_8bit_ETD_NoBar_NoOverlay_013.tif')
# Out:
# ImageWidth has code 256
# ImageLength has code 257
# BitsPerSample has code 258
# Compression has code 259
# PhotometricInterpretation has code 262
# StripOffsets has code 273
# SamplesPerPixel has code 277
# RowsPerStrip has code 278
# StripByteCounts has code 279
# XResolution has code 282
# YResolution has code 283
# PlanarConfiguration has code 284
# ResolutionUnit has code 296
# ExifTag has code 34665
# FEI_HELIOS has code 34682

# %% [raw]
# In questo esempio aldilà dei tag universalmente riconosciuti sono presenti due tag custom (il 34665 e il 34682) i quali però sono presenti nelal registry del pacchetto tifffile e dunque correttamente presentati con il loro nome. Se poi andiamo a guardare i valori presenti ad ogni tag ci accorgiamo anche che:

# %%
def show_value_for_tags(tif_file):
    with tf.TiffFile(tif_file) as tif:
        page = tif.pages[0]
        for tag in page.tags:
            print(f"{tag.name} has a type of {type(tag.value)} and value: {tag.value}")

# %%
show_value_for_tags('./File_per_sem/tiffs_for_sem/DIC_60nm_17.tif')
# Out:
# NewSubfileType has a type of <enum 'FILETYPE'> and value: 0
# ImageWidth has a type of <class 'int'> and value: 1024
# ImageLength has a type of <class 'int'> and value: 768
# BitsPerSample has a type of <class 'int'> and value: 8
# Compression has a type of <enum 'COMPRESSION'> and value: 1
# PhotometricInterpretation has a type of <enum 'PHOTOMETRIC'> and value: 1
# ImageDescription has a type of <class 'str'> and value: 7l
# StripOffsets has a type of <class 'tuple'> and value: (726,)
# SamplesPerPixel has a type of <class 'int'> and value: 1
# RowsPerStrip has a type of <class 'int'> and value: 10000
# StripByteCounts has a type of <class 'tuple'> and value: (786432,)
# XResolution has a type of <class 'tuple'> and value: (1, 1)
# YResolution has a type of <class 'tuple'> and value: (1, 1)
# ResolutionUnit has a type of <enum 'RESUNIT'> and value: 1
# ...

# %% [raw]
# Cioè i tipi sono "buoni" tipi python per i quali la lavorazione sarà semplice. Basterà registrare il tag custom in cui tutti i dati sono presenti (in questo caso il 34862) all'interno del dizionario 'tag_finder' in load_matchers e inserie il corretto percorso al nuovo file contenente i matchers che si vogliono creare, dunque creare i matchers come da esempi degli altri matchers esistenti. Una volta fatto questo i dati saranno perfettamente visibili in nomad dal file nexus con le altre routine.

# %% [raw]
# La seconda possibilità, che non è così grave ma richiede un pò di parsing aggiuntivo, potrebbe essere qualcosa simile alla prossima estrazione di metadati da tif:

# %%
analyze_metadata_from_tif('./File_per_sem/tiffs_for_sem/run2_area_01.tif')
# Out:
# ImageWidth has code 256
# ImageLength has code 257
# BitsPerSample has code 258
# Compression has code 259
# PhotometricInterpretation has code 262
# Make has code 271
# Model has code 272
# StripOffsets has code 273
# Orientation has code 274
# SamplesPerPixel has code 277
# RowsPerStrip has code 278
# StripByteCounts has code 279
# PlanarConfiguration has code 284
# Software has code 305
# DateTime has code 306
# Artist has code 315
# 50431 has code 50431

# %%
show_value_for_tags('./File_per_sem/tiffs_for_sem/run2_area_01.tif')
# Out:
# ImageWidth has a type of <class 'int'> and value: 1536
# ImageLength has a type of <class 'int'> and value: 1331
# BitsPerSample has a type of <class 'int'> and value: 16
# Compression has a type of <enum 'COMPRESSION'> and value: 1
# PhotometricInterpretation has a type of <enum 'PHOTOMETRIC'> and value: 1
# Make has a type of <class 'str'> and value: TESCAN - http://www.tescan.com/
# Model has a type of <class 'str'> and value: TESCAN NISABA TESCAN NISABA
# ...

# %% [raw]
# In questo esempio possiamo notare che a volte i tags non sono registrati nella registry di tifffile per cui il loro nome corrisponderà all'ID del tag e possiamo anche avere dei valori che non sono tipi comodo o ben formattati come ci saremmo aspettati. Nel nostro caso ad esempio le informazioni di processo provengono da una serie di bytes che dunque andranno parsati per poi essere scritti dentro il file NeXus.

# %% [raw]
# Per il nostro esempio ho elaborato la seguente funzione che si basa sulla ricerca di espressioni regolari, ma potrebbe capitar un caso o leggermente diverso o toalmente differente per cui o leggere modifiche a questa funzione o una nuova routine di preparsing potrebbe essere necessaria.

# %%
def search_quantities(text):
    tag_dict={}
    pattern=r'([A-Z]\w+)\s*=\s*((?:(?!\\n)[^;,])+)'
    matches = re.findall(pattern, text)
    for name, value in matches:
        tag_dict[name] = value

    return tag_dict

# %% [raw]
# E con questo nuovo strumento si può creare una funzione che finalmente genera il nuovo dizionario di metadati.

# %%
def extract_metadata_from_tif(percorso):
    dictionar = {}
    with tf.TiffFile(percorso) as tiffile:
        dictionar["file_name"] = percorso.split("/")[-1] 
        for i, page in enumerate(tiffile.pages):
            mio_dict = {}
            for tag in page.tags:
                try:
                    if isinstance(tag.value, str) or isinstance(tag.value, float) or isinstance(tag.value, int):
                        mio_dict[tag.name] = tag.value
                    elif isinstance(tag.value, tuple):
                        pass
                        #mio_dict[tag.name] = list(tag.value)
                    elif isinstance(tag.value, bytes):
                        new = str(tag.value)
                        mio_dict.setdefault(tag.code, search_quantities(new))
                    elif isinstance(tag.value, dict):
                         mio_dict[tag.name] = tag.value
                except Exception:
                    mio_dict[tag.name] = "Non leggibile"
            dictionar[f"page_{i+1}"] = mio_dict
    return dictionar

# %% [raw]
# In pratica questa funzione legge il tif e per ogni pagina di questo file itera una lettura dei tags relativi a quella pagina e i valori corrispondenti.
# Se tali valori sono semplici numeri o stringhe procede a salvarli senza problemi nel dizionario di output come coppia chiave valore. Se invece sono tuple li trasforma prima in lista (ci piacciono di più le liste) e nel caso peggiore in cui siano bytes opera la trasformazioen di quei bytes in stringa e poi con la funzione di prima inizia a iterare in mezzo alla stringa ottenuta per cercare la quantità come prima. Infine, se i tags vengono letti con strutture annidate e riescono ad avere la forma di dizionari vengono semplicemente appesi al dizionario di uscita.
# Per cui la struttura finale sarà:
#
# dictionar:{
#     "file_name": "nome_tif_file_analizzato",
#     "pagina_1": {
#         I vari tags letti come coppia chiave valore
#     },
#     "pagina_2": ...
# }

# %%
extract_metadata_from_tif('./File_per_sem/tiffs_for_sem/run2_area_01.tif')
# Out:
# {'file_name': 'run2_area_01.tif',
#  'page_1': {'ImageWidth': 1536,
#   'ImageLength': 1331,
#   'BitsPerSample': 16,
#   'Compression': <COMPRESSION.NONE: 1>,
#   'PhotometricInterpretation': <PHOTOMETRIC.MINISBLACK: 1>,
#   'Make': 'TESCAN - http://www.tescan.com/',
#   'Model': 'TESCAN NISABA TESCAN NISABA',
#   'Orientation': <ORIENTATION.TOPLEFT: 1>,
#   'SamplesPerPixel': 1,
#   'RowsPerStrip': 2,
#   'PlanarConfiguration': <PLANARCONFIG.CONTIG: 1>,
#   'Software': 'TESCAN Essence Version 1.3.3.1, build 7979',
#   'DateTime': '2025:07:15 17:40:39',
#   'Artist': 'acian',
#   50431: {'AccFrames': '1',
#    'AccType': 'Line',
#    'Date': '2025-07-15',
#    'Device': 'TESCAN NISABA',
#    'DeviceModel': 'L7151',
#    'FullUserName': 'acian',
#    'ImageStripSize': '179',
#    'Magnification': '7180.1280174',
#    'MagnificationReference': '0.4188',
#    'OrigFileName': 'run2_area_01',
#    'PixelSizeX': '0.000000037973731',
#    'PixelSizeY': '0.000000037973731',
# ...

# %% [raw]
# E adesso riusciamo a visualizzare quasi del tutto correttamente il nostro dizionario. Dico quasi del tutto perché la nostra funzione restituisce i valori ottenuti come stringhe anche quando sono chiaramente numeri ma comunque nel plugin all'interno della funzione populate_group della classe matcher su cui i vari matchers sono costruti è prevista la corretta conversione di questi tipi in ciò che si richiede. Per ora noi stiamo solo analizzando la situazione in cui arriviamo quando ci troviamo di fronte a un nuovo file tif.

# %% [raw]
# Dunque per questa eventualità ci basterà riuscire ad arrivare a un output della fase pre-matching simile alla situazione sopra così che il metodo populate group una volta generati i matchers possa procedere con l'arricchimento del file NeXus.

# %% [raw]
# La terza eventualità è già più dolorosa, ma ancora non c'è da perdere la speranza...

# %% [raw]
# In questo caso il vostro SEM non è in grado di produrre un tiff o comunque anche se il tiff risulta presente la situazione è la seguente.

# %%
analyze_metadata_from_tif('./File_per_sem/tiffs_for_sem/2025_08_31_U2280_Electrodes_GePP_HR_3um.tif')
# Out:
# NewSubfileType has code 254
# ImageWidth has code 256
# ImageLength has code 257
# BitsPerSample has code 258
# Compression has code 259
# PhotometricInterpretation has code 262
# Make has code 271
# StripOffsets has code 273
# Orientation has code 274
# SamplesPerPixel has code 277
# RowsPerStrip has code 278
# StripByteCounts has code 279
# XResolution has code 282
# YResolution has code 283
# ResolutionUnit has code 296
# Software has code 305

# %%
extract_metadata_from_tif('./File_per_sem/tiffs_for_sem/2025_08_31_U2280_Electrodes_GePP_HR_3um.tif')
# Out:
# {'file_name': '2025_08_31_U2280_Electrodes_GePP_HR_3um.tif',
#  'page_1': {'NewSubfileType': <FILETYPE.UNDEFINED: 0>,
#   'ImageWidth': 512,
#   'ImageLength': 512,
#   'BitsPerSample': 8,
#   'Compression': <COMPRESSION.NONE: 1>,
#   'PhotometricInterpretation': <PHOTOMETRIC.MINISBLACK: 1>,
#   'Make': 'Raith GmbH, D-44227 Dortmund',
#   'Orientation': <ORIENTATION.TOPLEFT: 1>,
#   'SamplesPerPixel': 1,
#   'RowsPerStrip': 512,
#   'ResolutionUnit': <RESUNIT.NONE: 1>,
#   'Software': 'ESCOSY Plus'}}

# %% [raw]
# In questo caso ho proceduto, dopo avere individuato i tags e i loro ids, direttamente all'estrazione perché non abbiamo un vero problema di tipo con cui i metadati vengono presentati. Il problema reale è che in questo formato tiff i dati di processo non vengono salvati in tag custom e quindi non sono direttamente presenti all'interno del tiff. Per cui da qui si daramano le effettive due possibilità rimaste:

# %% [raw]
# Se i dati sono presenti in un ulteriore file esterno (di solito un file di testo) si può usare la routine successiva per scriverli all'interno del file tiff in un tag custom e quindi ci troveremmo in una situazione simile al caso precedente e possiamo seguire i passi spiegati prima per ottenere la visualizzazione del nostro file NeXus (nota che avendo l'immagine quella potrebbe essere salvata senza problemi in NeXus). A onore del vero, si potrebbe in linea di principio caricare il file di testo e generare una ulteriore lista di matchers, ma questo avrebbe richiesto la costruzione di una nuova funzione di parsing nel plugin. Inoltre questa si sarebbe dovuta raccordare e inserire all'interno del converter per microscopia elettronica dove comunque l'immagine in un formato disponibile avrebbe dovuto essere parsata per ottenerne l'array da inserire nel NeXus per la visualizzazione. Per cui la soluzione migliore sarebbe effettuare un minimo di pre-processing includendo i dati dentro il tiff sarebbe la soluzione migliore per usare il resto delle routine già presenti.

# %%
import configparser

file_path = "./File_per_sem/tiffs_for_sem/2025_08_31 U2280_Electrodes_GePP_HR_3um_TIFversion.ssc"

with open(file_path, encoding= "latin-1") as f:
    letto=f.read()
    print(letto)
# Out:
# [METADATA]
# Acc. Voltage=0.0kV
# Active Mode=10kv_HC_CO_Work2
# Average Count=1
# Average Type=Moving Frame Averaging
# Date=2025/08/31
# Detector=SE2
# FoV=400.0µm
# Focus/WD=7.098mm
# Pixel Dwelltime=2µs
# Point Average=1
# Position U=1.0370mm
# Position V=2.4965mm
# Probe Current=20.5pA
# Project=%UserRoot%Project\New.DSK
# Stage R=0.0000mm
# Stage T=0.0000mm
# Stage X=18.0453mm
# Stage Y=-39.3926mm
# Stage Z=25.6202mm
# Step Size=0.7812µm
# Time=21:25:07
# User=Giubertoni
# Write field=200µm
# [SLOWSCAN]
# Bitmap=2025_08_31 U2280_Electrodes_GePP_HR_3um_TIFversion.tif
# DataZone=Damiano_SEM
# LocalOriginUV=1.036989,2.496478
# LowerLeftUV=0.836989,2.296478
# RotationUV=0
# ScanSignal=A
# ScanSource=SEM
# StageUV=6.974755,25.554795
# UpperRightUV=1.236989,2.696478

# %%
import json
file_path = "./File_per_sem/tiffs_for_sem/2025_08_31 U2280_Electrodes_GePP_HR_3um_TIFversion.ssc"

# regex per dividere chiave=valore
line_pattern = r'^([^=]+?)\s*=\s*(.+)$'
# regex per estrarre numero + unità, se presente
num_unit_pattern = r'^([+-]?\d+(?:\.\d+)?(?:[eE][+-]?\d+)?)\s*([^\d\s]*)$'

with open(file_path, encoding="latin-1") as f:
    new_dict={}
    for line in f:
        line = line.strip()
        match = re.match(line_pattern, line)
        if not match:
            continue
        
        name, raw_value = match.groups()
        raw_value = raw_value.strip()
        
        # provo a separare numero e unità
        mu = re.match(num_unit_pattern, raw_value)
        if mu:
            value, unit = mu.groups()
            value = float(value)
            second_string = f"with unit {unit}" if unit is not None else None
            new_dict.setdefault(name, value)
        else:
            # non è un numero → lascio stringa intera
            new_dict.setdefault(name, raw_value)

json_str = json.dumps(new_dict)
print(json_str)
# Out:
# {"Acc. Voltage": 0.0, "Active Mode": "10kv_HC_CO_Work2", "Average Count": 1.0, "Average Type": "Moving Frame Averaging", "Date": "2025/08/31", "Detector": "SE2", "FoV": 400.0, "Focus/WD": 7.098, "Pixel Dwelltime": 2.0, "Point Average": 1.0, "Position U": 1.037, "Position V": 2.4965, "Probe Current": 20.5, "Project": "%UserRoot%Project\\New.DSK", "Stage R": 0.0, "Stage T": 0.0, "Stage X": 18.0453, "Stage Y": -39.3926, "Stage Z": 25.6202, "Step Size": 0.7812, "Time": "21:25:07", "User": "Giubertoni", "Write field": 200.0, "Bitmap": "2025_08_31 U2280_Electrodes_GePP_HR_3um_TIFversion.tif", "DataZone": "Damiano_SEM", "LocalOriginUV": "1.036989,2.496478", "LowerLeftUV": "0.836989,2.296478", "RotationUV": 0.0, "ScanSignal": "A", "ScanSource": "SEM", "StageUV": "6.974755,25.554795", "UpperRightUV": "1.236989,2.696478"}

# %% [raw]
# Ci siamo così preparati la nostra struttura come dizionario json così da mandarlo alla routine in C per scriverne il nuovo custom tag con i dati appena estratti

# %% [raw]
# La funzione è presa dal modulo metadata_add.c che si trova nella source del codice. Questa routine si prende il codice del nuovo tag da scrivere (ovviamente ti consiglio di usare codici uguali per strumenti uguali e codici diversi per strumenti diversi).

# %%
from cffi import FFI
ffi = FFI()
# Definizione della funzione presente nella libreria C
ffi.cdef("""
    int write_custom_tag(const char* filename,
                          unsigned short tag_code,
                          const char* tag_name,
                          const char* tag_value);
""")

lib = ffi.dlopen("./libmetadata_add.so")  # carica la libreria compilata

file_tiff = "./2025_08_31_U2280_Electrodes_GePP_HR_3um.tif"
tag_code = 60000
tag_name = "RAITH_VELION"
tag_value = json_str
# Converti le stringhe in bytes per CFFI
file_tiff_b = file_tiff.encode('utf-8')
tag_name_b = tag_name.encode('utf-8')
tag_value_b = tag_value.encode('utf-8')

with tf.TiffFile(file_tiff) as tiff:
    for count, page in enumerate(tiff.pages):
        if tag_code not in page.tags:
            res = lib.write_custom_tag(file_tiff_b, tag_code, tag_name_b, tag_value_b)
            if res == 0:
                print(f"Tag scritto con successo nella pagina {count}")
            else:
                print(f"Errore scrittura tag, codice: {res}")
        else:
            print(f"Tag {tag_code} già presente nella pagina {count}")
# Out:
# Tag scritto con successo nella pagina 0
# TIFFFetchNormalTag: Warning, ASCII value for tag "Make" contains null byte in value; value incorrectly truncated during reading due to implementation limitations.

# %%
with tf.TiffFile('./2025_08_31_U2280_Electrodes_GePP_HR_3um.tif') as tiff:
    for page in tiff.pages:
        for tag in page.tags:
            print (f"{tag.name}: {tag.value} and code {tag.code}")
# Out:
# NewSubfileType: 0 and code 254
# ImageWidth: 512 and code 256
# ImageLength: 512 and code 257
# BitsPerSample: 8 and code 258
# Compression: 1 and code 259
# PhotometricInterpretation: 1 and code 262
# Make: Raith GmbH, D-44227 Dortmund and code 271
# StripOffsets: (266, 8458, 16650, 24842, 33034, 41226, 49418, 57610, 65802, 73994, 82186, 90378, 98570, 106762, 114954, 123146, 131338, 139530, 147722, 155914, 164106, 172298, 180490, 188682, 196874, 205066, 213258, 221450, 229642, 237834, 246026, 254218) and code 273
# Orientation: 1 and code 274
# SamplesPerPixel: 1 and code 277
# RowsPerStrip: 16 and code 278
# StripByteCounts: (8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192, 8192) and code 279
# XResolution: (0, 1) and code 282
# YResolution: (0, 1) and code 283
# PlanarConfiguration: 1 and code 284
# ResolutionUnit: 1 and code 296
# ...

# %% [raw]
# Se invece per un motivo qualsiasi non si abbiano a disposizione file tiff su cui lavorare ma comunque si vogliono aggingere i tags all'immagine da file esterno si può provare ad integrare il metodo precedente rendendolo operativo tramite il pacchetto PIL. Oppure se pur avendo un tiff non si hanno parametri ulteriori da aggiungere potreste comunque caricare l'array e il plugin automaticamente caricherebbe i matchers chiamati base_matchers che permettono di scrivere il nome dello strumento (preso dal campo Make) e il software utilizzato per ottenere l'immagine (preso dal campo Software) i quali come potete notare dagli esempi precedenti stanno negli ids universalmente riconosciuti e nel caso del FEI_HELIOS ad esempio sono comunque leggibili all'interno del tag custom.

# %% [raw]
# Infine se non avete a disposizione nessun file immagine rinunciate per sempre =) scherzo ma spero vi venga in mente qualcosa.
#
# Ciaooooo!
